# %% [markdown]
# **Enrollment No.: 2401840116064**

# %% [markdown]
# **Practical 4**

# %% [markdown]
# AIM: Perform Exploratory Data Analysis (EDA) using descriptive statistics and
# identify trends in datasets.

# %% [markdown]
# **Step 1: Import Libraries**

# %%
#Import pandas library
import pandas as pd
#Import matplotlib library
import matplotlib.pyplot as plt

# %% [markdown]
# **Step 2: Create Dataset**

# %%
#create dataset.
df={
    "Month": ["January", "Februay", "March", "April", "May", "June", "Jully", "August","September", "October", "NMovember", "December"],
    "Units_Sold": [120, 135, 150, 145, 160, 175, 180, 170, 190, 210, 230, 250],
    "Revenue": [120000, 135000, 150000, 145000, 160000, 175000, 180000, 170000, 190000, 210000, 230000, 250000],
    "Profit": [20000, 23000, 52000, 24000, 27000, 30000, 31000, 29000, 33000, 37000, 41000, 45000]
}

df = pd.DataFrame(df)
#Print Dataframe
df
# Out:
#         Month  Units_Sold  Revenue  Profit
# 0     January         120   120000   20000
# 1     Februay         135   135000   23000
# 2       March         150   150000   52000
# 3       April         145   145000   24000
# 4         May         160   160000   27000
# 5        June         175   175000   30000
# 6       Jully         180   180000   31000
# 7      August         170   170000   29000
# 8   September         190   190000   33000
# 9     October         210   210000   37000
# 10  NMovember         230   230000   41000
# 11   December         250   250000   45000

# %% [markdown]
# **Step 3: Inspect The Dataset**

# %%
#Display First Five rows.
df.head()
# Out:
#      Month  Units_Sold  Revenue  Profit
# 0  January         120   120000   20000
# 1  Februay         135   135000   23000
# 2    March         150   150000   52000
# 3    April         145   145000   24000
# 4      May         160   160000   27000

# %%
#Display the no of rows and columns.
df.shape
# Out:
# (12, 4)

# %%
#Display name of All the columns.
df.columns
# Out:
# Index(['Month', 'Units_Sold', 'Revenue', 'Profit'], dtype='object')

# %%
#Display info about dataset.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Month       12 non-null     object
#  1   Units_Sold  12 non-null     int64
#  2   Revenue     12 non-null     int64
#  3   Profit      12 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 516.0+ bytes

# %% [markdown]
# **Step 4: Generate Discriptive Statistic**

# %%
#Display Statistics of Numeric Columns.
df.describe()
# Out:
#        Units_Sold        Revenue        Profit
# count   12.000000      12.000000     12.000000
# mean   176.250000  176250.000000  32666.666667
# std     38.737168   38737.167963   9528.267355
# min    120.000000  120000.000000  20000.000000
# 25%    148.750000  148750.000000  26250.000000
# 50%    172.500000  172500.000000  30500.000000
# 75%    195.000000  195000.000000  38000.000000
# max    250.000000  250000.000000  52000.000000

# %% [markdown]
# **Step 5:  Claculate the avg no. of units sold per month**

# %%
#Display Avg number of Units sold per month.
average_units = df["Units_Sold"].mean()
#DIsplay Result.
print("Average no. of units sold per month:", average_units)
# Out:
# Average no. of units sold per month: 176.25

# %% [markdown]
# **Step 6: Calculate Median**

# %%
#Calculate the median.
median_units = df["Units_Sold"].median()
#DIsplay Result.
print("Median no. of units sold per month:", median_units)
# Out:
# Median no. of units sold per month: 172.5

# %% [markdown]
# **Step 7: Calculate Max Min**

# %%
#Find thye highest no. of units sold in mounth.
maximun_units = df["Units_Sold"].max()

#Find thye highest no. of units sold in mounth.
minimun_units = df["Units_Sold"].min()

#Display Result.
print("Maximum no. of units sold in a month:", maximun_units)
print("Minimum no. of units sold in a month:", minimun_units)
# Out:
# Maximum no. of units sold in a month: 250
# Minimum no. of units sold in a month: 120

# %% [markdown]
# **Step 8: Calculate Standard Deviation**

# %%
#Display SD
std_unit = df["Units_Sold"].std()
#Display the Result.
print("Standard Deviation:", std_unit)
# Out:
# Standard Deviation: 38.73716796331634

# %% [markdown]
# **Step 9: Find thye mounth with Highest Sales**

# %%
#Find the index of row having max revenue.
max_revenue_index = df["Revenue"].idxmax()
#Display the result (the index itself).
print("Row index with highest sales:", max_revenue_index)

#Retrieve the month corresponding to that index
month_with_highest_sales = df.loc[max_revenue_index, "Month"]

# Find highest_revenue value using the original numeric index
highest_revenue = df.loc[max_revenue_index, "Revenue"]

#Display results.
print("Month with highest sales:", month_with_highest_sales)
print("Highest revenue:", highest_revenue)
# Out:
# Row index with highest sales: 11
# Month with highest sales: December
# Highest revenue: 250000

# %% [markdown]
# **Step 10: Find the Month with lowest sale**

# %%
#Find the index of row having min revenue.
min_revenue_index = df["Revenue"].idxmin()
#Display the result (the index itself).
print("Row index with lowest sales:", min_revenue_index)

#Retrieve the month corresponding to that index
month_with_lowest_sales = df.loc[min_revenue_index, "Month"]

# Find lowest_revenue value using the original numeric index
lowest_revenue = df.loc[min_revenue_index, "Revenue"]

#Display results.
print("Month with lowest sales:", month_with_lowest_sales)
print("Lowest revenue:", lowest_revenue)
# Out:
# Row index with lowest sales: 0
# Month with lowest sales: January
# Lowest revenue: 120000

# %% [markdown]
# **Step 11: Calculate total Revenue**

# %%
#Diaplay total Revenue
total_revenue = df["Revenue"].sum()
#Display Result
print("Total Revenue:", total_revenue)
# Out:
# Total Revenue: 2115000

# %% [markdown]
# **Step 12: Calculate the total Profit Generated per year**

# %%
#Display Total Profit per yr
total_profit = df["Profit"].sum()
#Display Result
print("Total Profit:", total_profit)
# Out:
# Total Profit: 392000

# %% [markdown]
# **Step 13: Identify the Sales Trend**

# %%
#create a Line Chat to visualize monthly revenue.
plt.figure(figsize=(10, 5))

# Plot month on the x-axis and Revenue on the y-axis.
plt.plot(df["Month"], df["Revenue"], marker="o")

#Add a title on Graph.
plt.title("Monthly Revenue Trend")

#lable the X-axis.
plt.xlabel("Month")

#lable the Y-axis.
plt.ylabel("Revenue")

#Rotate Month name for batter readability.
plt.xticks(rotation=45)

#Display Graph.
plt.show()

# %% [markdown]
# **Step 14: Analyze the Profit Trend**

# %%
#Create a Line chart for Monthly Profit
plt.figure(figsize=(10, 5))

# Plot month on the x-axis and Profit on the y-axis.
plt.plot(df["Month"], df["Profit"], marker="o")

#Add a title on Graph.
plt.title("Monthly Profit Trend")

#lable the X-axis.
plt.xlabel("Month")

#lable the Y-axis.
plt.ylabel("Profit")

#Rotate Month name for batter readability.
plt.xticks(rotation=45)

#Display Graph.
plt.show()

# %% [markdown]
# **Step 15: Compare Revenue And Profit**

# %%
#Create a Line chart to compare Revenue and Profit.
plt.figure(figsize=(10, 5))

#Plot Revenue.
plt.plot(df["Month"], df["Revenue"], marker="o", label="Revenue")

#Plot Profit.
plt.plot(df["Month"], df["Profit"], marker="o", label="Profit")

#Add a title on Graph.
plt.title("Comparison of Revenue and Profit")

#lable the X-axis.
plt.xlabel("Month")

#lable the Y-axis.
plt.ylabel("Amount")

#Display lagend to identify two lines.
plt.legend()

#Display Graph.
plt.show()

# %% [markdown]
# **Step 16:Identify Growth in Sales**

# %%
#Calculate the % change in  Revenue from 1 month to next.
df["Revenue_Growth_%"] = df["Revenue"].pct_change() * 100

#DIsplay the Updated Dataset.
df
# Out:
#         Month  Units_Sold  Revenue  Profit  Revenue_Growth_%
# 0     January         120   120000   20000               NaN
# 1     Februay         135   135000   23000         12.500000
# 2       March         150   150000   52000         11.111111
# 3       April         145   145000   24000         -3.333333
# 4         May         160   160000   27000         10.344828
# 5        June         175   175000   30000          9.375000
# 6       Jully         180   180000   31000          2.857143
# 7      August         170   170000   29000         -5.555556
# 8   September         190   190000   33000         11.764706
# 9     October         210   210000   37000         10.526316
# 10  NMovember         230   230000   41000          9.523810
# 11   December         250   250000   45000          8.695652

# %% [markdown]
# **Step 17: Identify the Month With Increasing Revenue**

# %%
#Filter Dataset to display only these months where revenue
increasing_sales = df[df["Revenue_Growth_%"]>0]
#DIsplay the Updated Dataset.
increasing_sales
# Out:
#         Month  Units_Sold  Revenue  Profit  Revenue_Growth_%
# 1     Februay         135   135000   23000         12.500000
# 2       March         150   150000   52000         11.111111
# 4         May         160   160000   27000         10.344828
# 5        June         175   175000   30000          9.375000
# 6       Jully         180   180000   31000          2.857143
# 8   September         190   190000   33000         11.764706
# 9     October         210   210000   37000         10.526316
# 10  NMovember         230   230000   41000          9.523810
# 11   December         250   250000   45000          8.695652

# %% [markdown]
# **Step 18: Save the EDA Result**

# %%
df.to_csv("EDA_Sales_Analysis.csv", index=False)

print("CSV file saved Successfully")
# Out:
# CSV file saved Successfully

# %% [markdown]
# **Step 19: Download  CSV In Google colabe**

# %%
from google.colab import files

files.download("EDA_Sales_Analysis.csv")
